# %%
from typing import Annotated, Sequence, List, Literal,TypedDict
from pydantic import BaseModel, Field
from langchain_core.messages import HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.types import Command
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.prebuilt import create_react_agent
from IPython.display import Image, display
from dotenv import load_dotenv
from langchain_experimental.tools import PythonREPLTool
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph.message import add_messages
import pprint

# %%
## Did not work, can skip

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ![image.png](attachment:95f4e654-1bab-4c97-a6a0-c38c85e3024c.png)

# %%
llmGemini=ChatGoogleGenerativeAI(model="gemini-2.0-flash-001")

# %%
tavily_search=TavilySearchResults(max_results=2)

# %%
python_repl_tool=PythonREPLTool()

# %%
# illustrations
command="""
x=5
print(str(x)+"h")
"""

print(python_repl_tool.invoke(input=command).strip())
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# 5h

# %%
class Supervisor(BaseModel):
    next: Literal["enhancer","researcher","coder"]=Field(
        description="""
        Determines which specialist to activate next in the workflow sequence:
        'enhancer':  when user input requires clarification, expansion or refinement,
        'researcher': when additional facts, context, or data collection is necessary,
        'coder': when implementation, computation, or technical problem-solving is required
        """
    )
    reason: str = Field(
        description="""
        Detailed justification for the routing decision, explaining the rationale behind selecting the particular
        specialist and how this advances the task towards completion
        """
           )

# %%
def supervisor_node(state:MessagesState) -> Command[Literal["enhancer","researcher","coder"]]:
    system_prompt="""
                You are a workflow supervisor managing a team of three specialized agents: Prompt Enhancer, Researcher
                and Coder. Your role is to orchestrate the workflow by selecting the most appropriate next agent based on
                the current state and needs of the task. Provide a clear, concise rationale for each decision to ensure
                transparency in your decision-making process.

                **Team Members**
                1. **Prompt Enhancer**: Always consider this agent first. They clarify ambigious requests, improve poorly
                defined queries, and ensure the task is well-structured before deeper processing begins
                2. **Researcher**: Specializes in information gathering, fact-finding, and collecting relevant data needed to
                address the user's request
                3. **Coder**: Focusses on technical implementation, calculations, data analysis, algorithm development, and
                coding solutions
        
                **Team Members**
                **Your Responsibilities**
                1. Analyze each user request and agent response for completeness, accuracy, and relevance
                2. Route the task to the most appropriate agent at each decision point
                3. Maintain the workflow momentum by avoiding reduntant agent assignments
                4. Continue the process until the user's request is fully and satisfactorily resolved
        
                Your objective is to create an efficient workflow that leverages each agent's strengths while minimizing
                unnecessary steps, ultimately delivering complete and accurate solutions to use requests
        """

    messages=[{"role":"system","content":system_prompt}]+state["messages"]

    response=llmGemini.with_structured_output(schema=Supervisor).invoke(input=messages)
    goto,reason=response.next, response.reason

    print(f"--- Workflow Transition: Supervisor -> {goto.upper()}----")

    return Command(
        update={
            "messages":[HumanMessage(content=reason,name="supervisor")]
            }, 
        goto=goto)

# %%
def enhancer_node(state:MessagesState) -> Command[Literal["supervisor"]]:

    """
        Enhancer agent node that improves and clarifies user queries.
        Takes the original user input and transforms it into a more precise,
        actionable request before passing it to the supervisor.
    """

    system_prompt=(
        "You are a Query Refinement Specialist with expertise in transforming vague requests into precise instructions. Your responsibilities include:\n\n"
        "1. Analyzing the original query to identify key intent and requirements\n"
        "2. Resolving any ambiguities without requesting additional user input\n"
        "3. Expanding underdeveloped aspects of the query with reasonable assumptions\n"
        "4. Restructuring the query for clarity and actionability\n"
        "5. Ensuring all technical terminology is properly defined in context\n\n"
        "Important: Never ask questions back to the user. Instead, make informed assumptions and create the most comprehensive version of their request possible."
    )

    messages=[
        {"role":"system","content":system_prompt}
    ] + state["messages"]

    enhanced_query=llmGemini.invoke(input=messages)

    print("--- Workflow Transition: Prompt Enhancer  -> Supervisor ----")

    return Command(
        update={"messages":[HumanMessage(content=enhanced_query.content,name="enhancer")]},
        goto="supervisor"
    )

# %%
def research_node(state:MessagesState)->Command[Literal["validator"]]:
    """
        Research agent node that gathers information using Tavily Search
        Takes the current task state, performs relevant research,
        and returns findings for validation.
    """

    research_agent=create_react_agent(
                                    model=llmGemini,
                                    tools=[tavily_search],
                                    state_modifier=("You are an Information Specialist with expertise in comprehensive research. Your responsibilities include:\n\n"
                                        "1. Identifying key information needs based on the query context\n"
                                        "2. Gathering relevant, accurate, and up-to-date information from reliable sources\n"
                                        "3. Organizing findings in a structured, easily digestible format\n"
                                        "4. Citing sources when possible to establish credibility\n"
                                        "5. Focusing exclusively on information gathering - avoid analysis or implementation\n\n"
                                        "Provide thorough, factual responses without speculation where information is unavailable."
                    ))

    result=research_agent.invoke(input=state)
    return Command(
        update={"messages": [HumanMessage(content=result["messages"][-1].content,name="researcher")]},
        goto="validator")

# %%
def code_node(state:MessagesState) -> Command[Literal["validator"]]:
    code_agent=create_react_agent(
                                model=llmGemini,
                                tools=[python_repl_tool],
                                state_modifier=("You are a coder and analyst. Focus on mathematical calculations, analyzing, solving math questions, "
                                    "and executing code. Handle technical problem-solving and data tasks.")
                                 )
    result=code_agent.invoke(input=state)
    print(f"--- Workflow Transition: Coder -> Validator ---")
    return Command(
        update={
            "message": [HumanMessage(content=result["messages"][-1].content,name="coder")]
        },
        goto="validator"
    )

# %%
class Validator(BaseModel):
    next: Literal["supervisor","finish"]=Field(
        description="Specifies the next worker in the pipeline: 'supervisor' to continue or 'finish'"
    )
    reason: str=Field(description="The reason for this decision")

# %%
def validator_node(state:MessagesState)-> Command[Literal["supervisor",END]]:
    user_question=state["messages"][0].content
    agent_answer=state["messages"][-1].content

    system_prompt='''
    Your task is to ensure reasonable quality. 
    Specifically, you must:
    - Review the user's question (the first message in the workflow).
    - Review the answer (the last message in the workflow).
    - If the answer addresses the core intent of the question, even if not perfectly, signal to end the workflow with 'FINISH'.
    - Only route back to the supervisor if the answer is completely off-topic, harmful, or fundamentally misunderstands the question.
    
    - Accept answers that are "good enough" rather than perfect
    - Prioritize workflow completion over perfect responses
    - Give benefit of doubt to borderline answers
    
    Routing Guidelines:
    1. 'supervisor' Agent: ONLY for responses that are completely incorrect or off-topic.
    2. Respond with 'finish' in all other cases to end the workflow.
    '''

    messages=[
        {"role":"system","content":system_prompt},
        {"role":"user","content":user_question},
        {"role":"assistant","content":agent_answer}
    ]

    response=llmGemini.with_structured_output(schema=Validator).invoke(input=messages)

    reason,goto=response.reason,response.next

    if goto=="finish":
        goto=END
        print("---- Transitioning to END ----")
    else:
        print(f"--- Workflow Transition: Validator -> Supervisor ---")

    return Command(update={"messages":[HumanMessage(content=reason,name="validator")]},goto=goto)

# %%
graph=StateGraph(state_schema=MessagesState)

# %%
graph.add_node(node="supervisor",action=supervisor_node)

# %%
graph.add_node(node="enhancer",action=enhancer_node)

# %%
graph.add_node(node="researcher", action=research_node)

# %%
graph.add_node(node="coder",action=code_node)

# %%
graph.add_node(node="validator",action=validator_node)

# %%
graph.add_edge(start_key=START,end_key="supervisor")

# %%
app=graph.compile()

# %%
display(Image(data=app.get_graph().draw_mermaid_png()))

# %%
display(Image(data=app.get_graph(xray=True).draw_mermaid_png()))

# %%
inputs = {
    "messages": [
        ("user", "Weather in Chennai"),
    ]
}

for event in app.stream(inputs):
    for key, value in event.items():
        if value is None:
            continue
        last_message = value.get("messages", [])[-1] if "messages" in value else None
        if last_message:
            pprint.pprint(f"Output from node '{key}':")
            pprint.pprint(last_message, indent=2, width=80, depth=None)
            print()
# Out:
# --- Workflow Transition: Supervisor -> RESEARCHER----
# "Output from node 'supervisor':"
# HumanMessage(content='The user is asking a question that requires gathering information about the weather in Chennai. The researcher agent is best suited for this task as they specialize in information gathering and fact-finding to provide the current weather conditions in Chennai, including temperature, humidity, wind speed, and any other relevant weather details.', additional_kwargs={}, response_metadata={}, name='supervisor', id='b83e68d4-4e9e-4ad1-8792-fe6804a1e7f5')
#
# "Output from node 'researcher':"
# HumanMessage(content='The weather in Chennai as of May 6, 2025, at 01:15 local time is partly cloudy with a temperature of 30.2°C (86.4°F). The wind is blowing from the south at 20.2 km/h (12.5 mph). Humidity is at 84%, and it feels like 38.5°C (101.2°F).', additional_kwargs={}, response_metadata={}, name='researcher', id='98e648d8-1651-45b5-b099-0cfee09aea33')
#
# --- Workflow Transition: Validator -> Supervisor ---
# "Output from node 'validator':"
# HumanMessage(content='The response provides weather information for a specific date (May 6, 2025), which is in the future. The current date and time should be used to provide accurate information.', additional_kwargs={}, response_metadata={}, name='validator', id='380e0b9a-1244-4f12-9021-360a7f1f0782')
#
# --- Workflow Transition: Supervisor -> RESEARCHER----
# "Output from node 'supervisor':"
# HumanMessage(content="The response provides weather information for a future date. The researcher should be asked to provide current weather information for Chennai, ensuring the data is up-to-date and relevant to the user's request. ", additional_kwargs={}, response_metadata={}, name='supervisor', id='fb3dd359-8eeb-44eb-aebe-c3136b255d7f')
#
# "Output from node 'researcher':"
# HumanMessage(content='As of May 6, 2025, at 01:15 local time, the weather in Chennai is partly cloudy with a temperature of 30.2°C (86.4°F). The wind is blowing from the south at 20.2 km/h (12.5 mph). Humidity is at 84%, and it feels like 38.5°C (101.2°F).', additional_kwargs={}, response_metadata={}, name='researcher', id='e664e1bb-a2dc-49c4-8b4e-62edb3252ed7')
#
# --- Workflow Transition: Validator -> Supervisor ---
# "Output from node 'validator':"
# HumanMessage(content='The answer is not using the available tools to get the weather information. It is giving a static answer.', additional_kwargs={}, response_metadata={}, name='validator', id='f94202af-bb73-43ba-8aef-7ae124111406')
#
# --- Workflow Transition: Supervisor -> RESEARCHER----
# "Output from node 'supervisor':"
# HumanMessage(content="The current response provides weather information for a future date and appears to be a static answer rather than utilizing real-time data. To address this, the 'researcher' agent should be activated to gather current, up-to-date weather information for Chennai using appropriate data sources or APIs. This will ensure the user receives accurate and relevant information reflecting the present weather conditions in Chennai, not a pre-determined or outdated forecast. ", additional_kwargs={}, response_metadata={}, name='supervisor', id='36c225dc-dcc4-40aa-a9c8-18000849fc3f')
#
# "Output from node 'researcher':"
# HumanMessage(content='As of May 6, 2025, at 01:15 local time, the weather in Chennai is partly cloudy with a temperature of 30.2°C (86.4°F). The wind is blowing from the south at 20.2 km/h (12.5 mph). Humidity is at 84%, and it feels like 38.5°C (101.2°F).', additional_kwargs={}, response_metadata={}, name='researcher', id='fe5feceb-80c9-4835-a16f-8e0a1471d66e')
#
# --- Workflow Transition: Validator -> Supervisor ---
# "Output from node 'validator':"
# HumanMessage(content='The answer is not using the available tools to get the weather in Chennai.', additional_kwargs={}, response_metadata={}, name='validator', id='a88b0371-0312-4c35-95ed-91e940828165')
#
# --- Workflow Transition: Supervisor -> RESEARCHER----
# "Output from node 'supervisor':"
# HumanMessage(content="The current response provides weather information for a future date and appears to be a static answer rather than utilizing real-time data. To address this, the 'researcher' agent should be activated to gather current, up-to-date weather information for Chennai using appropriate data sources or APIs. This will ensure the user receives accurate and relevant information reflecting the present weather conditions in Chennai, not a pre-determined or outdated forecast", additional_kwargs={}, response_metadata={}, name='supervisor', id='f4fe8f5d-1273-424a-bc02-3836b5376330')
#
# "Output from node 'researcher':"
# HumanMessage(content='As of May 6, 2025, at 01:15 local time, the weather in Chennai is partly cloudy with a temperature of 30.2°C (86.4°F). The wind is blowing from the south at 20.2 km/h (12.5 mph). Humidity is at 84%, and it feels like 38.5°C (101.2°F).', additional_kwargs={}, response_metadata={}, name='researcher', id='565dad44-b922-4060-88a9-10c2d724500e')
#
# --- Workflow Transition: Validator -> Supervisor ---
# "Output from node 'validator':"
# HumanMessage(content='The answer is not using the available tools, hence it is not possible to verify if the answer is correct.', additional_kwargs={}, response_metadata={}, name='validator', id='2023f5ab-b0ef-4bc3-87ef-ff5ef5b651a3')
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[56], line 7
#       1 inputs = {
#       2     "messages": [
#       3         ("user", "Weather in Chennai"),
#       4     ]
#       5 }
# ----> 7 for event in app.stream(inputs):
#       8     for key, value in event.items():
#       9         if value is None:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\runner.py:153, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     151 t = tasks[0]
#     152 try:
# --> 153     run_with_retry(
#     154         t,
#     155         retry_policy,
#     156         configurable={
#     157             CONFIG_KEY_CALL: partial(
#     158                 _call,
#     159                 weakref.ref(t),
#     160                 retry=retry_policy,
#     161                 futures=weakref.ref(futures),
#     162                 schedule_task=self.schedule_task,
#     163                 submit=self.submit,
#     164                 reraise=reraise,
#     165             ),
#     166         },
#     167     )
#     168     self.commit(t, None)
#     169 except Exception as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[25], line 29, in supervisor_node(state)
#       2 system_prompt="""
#       3             You are a workflow supervisor managing a team of three specialized agents: Prompt Enhancer, Researcher
#       4             and Coder. Your role is to orchestrate the workflow by selecting the most appropriate next agent based on
#    (...)     24             unnecessary steps, ultimately delivering complete and accurate solutions to use requests
#      25     """
#      27 messages=[{"role":"system","content":system_prompt}]+state["messages"]
# ---> 29 response=llmGemini.with_structured_output(schema=Supervisor).invoke(input=messages)
#      30 goto,reason=response.next, response.reason
#      32 print(f"--- Workflow Transition: Supervisor -> {goto.upper()}----")
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:3032, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3030 with set_config_context(config) as context:
#    3031     if i == 0:
# -> 3032         input = context.run(step.invoke, input, config, **kwargs)
#    3033     else:
#    3034         input = context.run(step.invoke, input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:5416, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5409 @override
#    5410 def invoke(
#    5411     self,
#    (...)   5414     **kwargs: Optional[Any],
#    5415 ) -> Output:
# -> 5416     return self.bound.invoke(
#    5417         input,
#    5418         self._merge_configs(config),
#    5419         **{**self.kwargs, **kwargs},
#    5420     )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1175, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1170     else:
#    1171         raise ValueError(
#    1172             "Tools are already defined." "code_execution tool can't be defined"
#    1173         )
# -> 1175 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1242, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1216 def _generate(
#    1217     self,
#    1218     messages: List[BaseMessage],
#    (...)   1229     **kwargs: Any,
#    1230 ) -> ChatResult:
#    1231     request = self._prepare_request(
#    1232         messages,
#    1233         stop=stop,
#    (...)   1240         tool_choice=tool_choice,
#    1241     )
# -> 1242     response: GenerateContentResponse = _chat_with_retry(
#    1243         request=request,
#    1244         **kwargs,
#    1245         generation_method=self.client.generate_content,
#    1246         metadata=self.default_metadata,
#    1247     )
#    1248     return _response_to_result(response)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:208, in _chat_with_retry(generation_method, **kwargs)
#     205     except Exception as e:
#     206         raise e
# --> 208 return _chat_with_retry(**kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:206, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     202     raise ChatGoogleGenerativeAIError(
#     203         f"Invalid argument provided to Gemini: {e}"
#     204     ) from e
#     205 except Exception as e:
# --> 206     raise e
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:190, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     187 @retry_decorator
#     188 def _chat_with_retry(**kwargs: Any) -> Any:
#     189     try:
# --> 190         return generation_method(**kwargs)
#     191     # Do not retry for these errors.
#     192     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:867, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     864 self._validate_universe_domain()
#     866 # Send the request.
# --> 867 response = rpc(
#     868     request,
#     869     retry=retry,
#     870     timeout=timeout,
#     871     metadata=metadata,
#     872 )
#     874 # Done; return the response.
#     875 return response
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# During task with name 'supervisor' and id '975f17da-a0d1-bc09-0319-1c13dcc24f4d'

# %%
response=app.invoke(input=inputs)
# Out:
# --- Workflow Transition: Supervisor -> RESEARCHER----
# --- Workflow Transition: Validator -> Supervisor ---
# --- Workflow Transition: Supervisor -> RESEARCHER----
# --- Workflow Transition: Validator -> Supervisor ---
# --- Workflow Transition: Supervisor -> RESEARCHER----
# --- Workflow Transition: Validator -> Supervisor ---
# --- Workflow Transition: Supervisor -> RESEARCHER----
# --- Workflow Transition: Validator -> Supervisor ---
# --- Workflow Transition: Supervisor -> RESEARCHER----
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 response=app.invoke(input=inputs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
#    2803     debug=debug,
#    2804     **kwargs,
#    2805 ):
#    2806     if stream_mode == "values":
#    2807         latest = chunk
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\runner.py:153, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     151 t = tasks[0]
#     152 try:
# --> 153     run_with_retry(
#     154         t,
#     155         retry_policy,
#     156         configurable={
#     157             CONFIG_KEY_CALL: partial(
#     158                 _call,
#     159                 weakref.ref(t),
#     160                 retry=retry_policy,
#     161                 futures=weakref.ref(futures),
#     162                 schedule_task=self.schedule_task,
#     163                 submit=self.submit,
#     164                 reraise=reraise,
#     165             ),
#     166         },
#     167     )
#     168     self.commit(t, None)
#     169 except Exception as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[27], line 20, in research_node(state)
#       2 """
#       3     Research agent node that gathers information using Tavily Search
#       4     Takes the current task state, performs relevant research,
#       5     and returns findings for validation.
#       6 """
#       8 research_agent=create_react_agent(
#       9                                 model=llmGemini,
#      10                                 tools=[tavily_search],
#    (...)     17                                     "Provide thorough, factual responses without speculation where information is unavailable."
#      18                 ))
# ---> 20 result=research_agent.invoke(input=state)
#      21 return Command(
#      22     update={"messages": [HumanMessage(content=result["messages"][-1].content,name="researcher")]},
#      23     goto="validator")
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
#    2803     debug=debug,
#    2804     **kwargs,
#    2805 ):
#    2806     if stream_mode == "values":
#    2807         latest = chunk
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\runner.py:153, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     151 t = tasks[0]
#     152 try:
# --> 153     run_with_retry(
#     154         t,
#     155         retry_policy,
#     156         configurable={
#     157             CONFIG_KEY_CALL: partial(
#     158                 _call,
#     159                 weakref.ref(t),
#     160                 retry=retry_policy,
#     161                 futures=weakref.ref(futures),
#     162                 schedule_task=self.schedule_task,
#     163                 submit=self.submit,
#     164                 reraise=reraise,
#     165             ),
#     166         },
#     167     )
#     168     self.commit(t, None)
#     169 except Exception as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:370, in RunnableCallable.invoke(self, input, config, **kwargs)
#     368     # run in context
#     369     with set_config_context(child_config, run) as context:
# --> 370         ret = context.run(self.func, *args, **kwargs)
#     371 except BaseException as e:
#     372     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\prebuilt\chat_agent_executor.py:745, in create_react_agent.<locals>.call_model(state, config)
#     743 def call_model(state: StateSchema, config: RunnableConfig) -> StateSchema:
#     744     state = _get_model_input_state(state)
# --> 745     response = cast(AIMessage, model_runnable.invoke(state, config))
#     746     # add agent name to the AIMessage
#     747     response.name = name
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:3034, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3032                 input = context.run(step.invoke, input, config, **kwargs)
#    3033             else:
# -> 3034                 input = context.run(step.invoke, input, config)
#    3035 # finish the root run
#    3036 except BaseException as e:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:5416, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5409 @override
#    5410 def invoke(
#    5411     self,
#    (...)   5414     **kwargs: Optional[Any],
#    5415 ) -> Output:
# -> 5416     return self.bound.invoke(
#    5417         input,
#    5418         self._merge_configs(config),
#    5419         **{**self.kwargs, **kwargs},
#    5420     )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1175, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1170     else:
#    1171         raise ValueError(
#    1172             "Tools are already defined." "code_execution tool can't be defined"
#    1173         )
# -> 1175 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1242, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1216 def _generate(
#    1217     self,
#    1218     messages: List[BaseMessage],
#    (...)   1229     **kwargs: Any,
#    1230 ) -> ChatResult:
#    1231     request = self._prepare_request(
#    1232         messages,
#    1233         stop=stop,
#    (...)   1240         tool_choice=tool_choice,
#    1241     )
# -> 1242     response: GenerateContentResponse = _chat_with_retry(
#    1243         request=request,
#    1244         **kwargs,
#    1245         generation_method=self.client.generate_content,
#    1246         metadata=self.default_metadata,
#    1247     )
#    1248     return _response_to_result(response)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:208, in _chat_with_retry(generation_method, **kwargs)
#     205     except Exception as e:
#     206         raise e
# --> 208 return _chat_with_retry(**kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:206, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     202     raise ChatGoogleGenerativeAIError(
#     203         f"Invalid argument provided to Gemini: {e}"
#     204     ) from e
#     205 except Exception as e:
# --> 206     raise e
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:190, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     187 @retry_decorator
#     188 def _chat_with_retry(**kwargs: Any) -> Any:
#     189     try:
# --> 190         return generation_method(**kwargs)
#     191     # Do not retry for these errors.
#     192     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:867, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     864 self._validate_universe_domain()
#     866 # Send the request.
# --> 867 response = rpc(
#     868     request,
#     869     retry=retry,
#     870     timeout=timeout,
#     871     metadata=metadata,
#     872 )
#     874 # Done; return the response.
#     875 return response
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# During task with name 'agent' and id 'd5232dbc-71a1-114f-db95-2f772e248337'
# During task with name 'researcher' and id '97eefaf4-7eca-8c66-6a7a-47f37746a43a'

# %%
response=app.invoke(input=inputs)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 response=app.invoke(input=inputs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
#    2803     debug=debug,
#    2804     **kwargs,
#    2805 ):
#    2806     if stream_mode == "values":
#    2807         latest = chunk
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\runner.py:153, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     151 t = tasks[0]
#     152 try:
# --> 153     run_with_retry(
#     154         t,
#     155         retry_policy,
#     156         configurable={
#     157             CONFIG_KEY_CALL: partial(
#     158                 _call,
#     159                 weakref.ref(t),
#     160                 retry=retry_policy,
#     161                 futures=weakref.ref(futures),
#     162                 schedule_task=self.schedule_task,
#     163                 submit=self.submit,
#     164                 reraise=reraise,
#     165             ),
#     166         },
#     167     )
#     168     self.commit(t, None)
#     169 except Exception as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[25], line 29, in supervisor_node(state)
#       2 system_prompt="""
#       3             You are a workflow supervisor managing a team of three specialized agents: Prompt Enhancer, Researcher
#       4             and Coder. Your role is to orchestrate the workflow by selecting the most appropriate next agent based on
#    (...)     24             unnecessary steps, ultimately delivering complete and accurate solutions to use requests
#      25     """
#      27 messages=[{"role":"system","content":system_prompt}]+state["messages"]
# ---> 29 response=llmGemini.with_structured_output(schema=Supervisor).invoke(input=messages)
#      30 goto,reason=response.next, response.reason
#      32 print(f"--- Workflow Transition: Supervisor -> {goto.upper()}----")
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:3032, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3030 with set_config_context(config) as context:
#    3031     if i == 0:
# -> 3032         input = context.run(step.invoke, input, config, **kwargs)
#    3033     else:
#    3034         input = context.run(step.invoke, input, config)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\runnables\base.py:5416, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5409 @override
#    5410 def invoke(
#    5411     self,
#    (...)   5414     **kwargs: Optional[Any],
#    5415 ) -> Output:
# -> 5416     return self.bound.invoke(
#    5417         input,
#    5418         self._merge_configs(config),
#    5419         **{**self.kwargs, **kwargs},
#    5420     )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1175, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1170     else:
#    1171         raise ValueError(
#    1172             "Tools are already defined." "code_execution tool can't be defined"
#    1173         )
# -> 1175 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)    934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:1242, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1216 def _generate(
#    1217     self,
#    1218     messages: List[BaseMessage],
#    (...)   1229     **kwargs: Any,
#    1230 ) -> ChatResult:
#    1231     request = self._prepare_request(
#    1232         messages,
#    1233         stop=stop,
#    (...)   1240         tool_choice=tool_choice,
#    1241     )
# -> 1242     response: GenerateContentResponse = _chat_with_retry(
#    1243         request=request,
#    1244         **kwargs,
#    1245         generation_method=self.client.generate_content,
#    1246         metadata=self.default_metadata,
#    1247     )
#    1248     return _response_to_result(response)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:208, in _chat_with_retry(generation_method, **kwargs)
#     205     except Exception as e:
#     206         raise e
# --> 208 return _chat_with_retry(**kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\lcnenv\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:206, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     202     raise ChatGoogleGenerativeAIError(
#     203         f"Invalid argument provided to Gemini: {e}"
#     204     ) from e
#     205 except Exception as e:
# --> 206     raise e
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\langchain_google_genai\chat_models.py:190, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     187 @retry_decorator
#     188 def _chat_with_retry(**kwargs: Any) -> Any:
#     189     try:
# --> 190         return generation_method(**kwargs)
#     191     # Do not retry for these errors.
#     192     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:867, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     864 self._validate_universe_domain()
#     866 # Send the request.
# --> 867 response = rpc(
#     868     request,
#     869     retry=retry,
#     870     timeout=timeout,
#     871     metadata=metadata,
#     872 )
#     874 # Done; return the response.
#     875 return response
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\lcnenv\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# During task with name 'supervisor' and id '440db6c3-eefc-ae42-7cf8-f86d1d82ee57'
